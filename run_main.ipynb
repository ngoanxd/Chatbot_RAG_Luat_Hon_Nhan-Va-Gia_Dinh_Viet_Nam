# %% [markdown]
# Kết nối Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Tải thư viện cần thiết

# %%
# !pip install langchain_core
# !pip install langchain_community
# !pip install faiss-cpu
# !pip install rank_bm25
# !pip install -u langchain-ollama
# !pip install -U langchain-huggingface

# %% [markdown]
# Khởi tạo môi trường llm

# %%
# 1. Cài đặt zstd
# !sudo apt-get update && sudo apt-get install -y zstd

# 2. Cài đặt Ollama lại từ đầu
# !curl -fsSL https://ollama.com/install.sh | sh

# 3.Chạy Ollama server ở chế độ nền
import subprocess
import time

# Chuyển hướng log ra file để tránh treo Cell
subprocess.Popen(['/usr/local/bin/ollama', 'serve'])

# Chờ 15 giây để server ổn định
time.sleep(15)

# Kiểm tra xem server có phản hồi không
# !curl http://localhost:11434

# Tải mô hình qwen
# !ollama pull qwen3

# %% [markdown]
# Gọi thư viện

# %%
from langchain_community.document_loaders import TextLoader
import matplotlib.pyplot as plt
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.documents import Document
import re
from langchain_community.llms import Ollama
from transformers import AutoTokenizer
from sentence_transformers import CrossEncoder
import os
from rank_bm25 import BM25Okapi
import json
import time
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Chạy file

# %%
# %cd /content/drive/MyDrive/Chatbot_RAG_Luat_Hon_Nhan-Va-Gia_Dinh_Viet_Nam

# %%
# !python main.py
